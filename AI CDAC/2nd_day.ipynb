# %%
import seaborn as sns           # sns is alias

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import numpy as np
from datetime import timedelta

# %%
from warnings import filterwarnings
filterwarnings("ignore")

# %%
ls = pd.Series(np.random.randn(200) , index = pd.date_range("1/1/2021" , periods=200))

# %%
ls
# Out:
# 2021-01-01   -1.051759
# 2021-01-02   -0.167092
# 2021-01-03    1.197121
# 2021-01-04   -0.120178
# 2021-01-05    0.972070
#                 ...
# 2021-07-15    0.129113
# 2021-07-16   -0.282743
# 2021-07-17    2.109759
# 2021-07-18   -0.191260
# 2021-07-19   -0.718022
# Freq: D, Length: 200, dtype: float64

# %%
ls.head()
# Out:
# 2021-01-01   -1.051759
# 2021-01-02   -0.167092
# 2021-01-03    1.197121
# 2021-01-04   -0.120178
# 2021-01-05    0.972070
# Freq: D, dtype: float64

# %%
ls = ls.cumsum()

# %%
ls
# Out:
# 2021-01-01   -1.051759
# 2021-01-02   -1.218851
# 2021-01-03   -0.021730
# 2021-01-04   -0.141908
# 2021-01-05    0.830162
#                 ...
# 2021-07-15   -1.378602
# 2021-07-16   -1.661345
# 2021-07-17    0.448414
# 2021-07-18    0.257153
# 2021-07-19   -0.460869
# Freq: D, Length: 200, dtype: float64

# %%
ls.plot(kind="line",c="r")
plt.title(" basic plot")
plt.show()

# %%
df = pd.DataFrame(
    np.random.randn(200, 5),
    index=ls.index,
    columns=["column_1", "column_2", "column_3", "column_4", "column_5"],
)

# %%
df = df.cumsum()

# %%
df
# Out:
#             column_1  column_2  column_3  column_4  column_5
# 2021-01-01  2.349307  0.775172  0.191135  1.408695 -0.685651
# 2021-01-02  3.470527 -1.864585 -1.329883  1.118287 -1.582340
# 2021-01-03  2.923278  1.068191 -1.069763  1.089566 -2.928994
# 2021-01-04  3.247278 -0.824457 -1.688045  0.543391 -3.024938
# 2021-01-05  3.540544 -1.002219 -0.870118 -0.442400 -2.492449
# ...              ...       ...       ...       ...       ...
# 2021-07-15  8.962885  1.468053 -0.964434 -2.443339  4.796345
# 2021-07-16  9.034875  1.554485 -0.786176 -3.360465  5.539058
# 2021-07-17  9.550779  4.275059 -1.737545 -2.707443  4.842479
# 2021-07-18  8.859686  5.354304 -2.380178 -1.874690  5.149778
# 2021-07-19  9.800626  6.984837 -1.231293 -1.731016  5.685990
#
# [200 rows x 5 columns]

# %%
df.head(10)
# Out:
#             column_1  column_2  column_3  column_4  column_5
# 2021-01-01  2.349307  0.775172  0.191135  1.408695 -0.685651
# 2021-01-02  3.470527 -1.864585 -1.329883  1.118287 -1.582340
# 2021-01-03  2.923278  1.068191 -1.069763  1.089566 -2.928994
# 2021-01-04  3.247278 -0.824457 -1.688045  0.543391 -3.024938
# 2021-01-05  3.540544 -1.002219 -0.870118 -0.442400 -2.492449
# 2021-01-06  2.672854 -0.419392 -3.125199  0.415201 -2.823563
# 2021-01-07  1.354921 -0.579842 -1.935555 -0.442895 -5.418675
# 2021-01-08  1.609486 -0.624936 -1.950494 -1.103548 -6.361250
# 2021-01-09  0.909590 -0.674270 -2.005372 -1.082397 -6.739446
# 2021-01-10  0.689047 -0.171683 -2.048567 -1.958298 -7.182853

# %%
plt.Figure(figsize=(8,8))
df.plot()
plt.show()

# %%
notes = [10,20,30,40,50,60,70,80,90,99]
study_hours = [2,3,4,5,6,7,8,9,5,6]
exam_notes = pd.DataFrame(notes,columns=["notes"])
exam_notes["study_hours"]=pd.Series(study_hours)

# %%
exam_notes.plot(x="study_hours",y="notes",color="red")
# Out:
# <Axes: xlabel='study_hours'>

# %%
x = pd.Series(["A","B","C","D"])
y = pd.Series([12,13,14,15])
df = pd.DataFrame({"Letters": x,"Numbers":y})

df.index = x

# %%
df
# Out:
#   Letters  Numbers
# A       A       12
# B       B       13
# C       C       14
# D       D       15

# %%
df.plot(kind="bar",color="green")
plt.xlabel("letters")
plt.ylabel("numbers")
# Out:
# Text(0, 0.5, 'numbers')

# %%
df = pd.DataFrame(np.random.rand(7,5) ,columns=["ROHAN","RAJ","RANI","VIHSU","YASHU"])

# %%
df.plot(figsize=(8,8),kind="bar")
# Out:
# <Axes: >

# %%
df.plot.bar(figsize=(8,8),stacked = True)
# Out:
# <Axes: >

# %%
df.plot(figsize=(8,8),kind="barh")
# Out:
# <Axes: >

# %%
df.plot.barh(figsize=(8,8),stacked = True)
# Out:
# <Axes: >

# %%
note1 = [23,34,45,67,54,67,34,78,56,78]
note2 = [65,54,67,34,67,45,34,67,45,34]
final_note = [34,45,32,56,43,23,56,43,56,34]

notes = pd.DataFrame({"note1":note1 , "note2":note2 , "final_note":final_note})

# %%
notes
# Out:
#    note1  note2  final_note
# 0     23     65          34
# 1     34     54          45
# 2     45     67          32
# 3     67     34          56
# 4     54     67          43
# 5     67     45          23
# 6     34     34          56
# 7     78     67          43
# 8     56     45          56
# 9     78     34          34

# %%
notes.plot.hist(figsize=(8, 8), alpha=0.5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
notes.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
notes['note1'].plot(kind="hist",alpha = 0.1 )
# Out:
# <Axes: ylabel='Frequency'>

# %%
notes.plot.hist(figsize=(8, 8), alpha=0.5,orientation = "horizontal")
# Out:
# <Axes: xlabel='Frequency'>

# %%
notes
# Out:
#    note1  note2  final_note
# 0     23     65          34
# 1     34     54          45
# 2     45     67          32
# 3     67     34          56
# 4     54     67          43
# 5     67     45          23
# 6     34     34          56
# 7     78     67          43
# 8     56     45          56
# 9     78     34          34

# %%
notes.head()
# Out:
#    note1  note2  final_note
# 0     23     65          34
# 1     34     54          45
# 2     45     67          32
# 3     67     34          56
# 4     54     67          43

# %%
notes.plot(kind="box")
# Out:
# <Axes: >

# %%
notes.plot(kind="scatter", x="note1", y="note2",color="red",grid=True)
# Out:
# <Axes: xlabel='note1', ylabel='note2'>
