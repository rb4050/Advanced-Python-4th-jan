# %%
import seaborn as sns           # sns is alias

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import numpy as np
from datetime import timedelta

# %%
from warnings import filterwarnings
filterwarnings("ignore")

# %%
ls = pd.Series(np.random.randn(200) , index = pd.date_range("1/1/2021" , periods=200))

# %%
ls
# Out:
# 2021-01-01   -0.022578
# 2021-01-02    0.029524
# 2021-01-03   -0.076704
# 2021-01-04   -0.072829
# 2021-01-05    0.504664
#                 ...
# 2021-07-15   -0.545848
# 2021-07-16    1.777947
# 2021-07-17    0.259797
# 2021-07-18    0.114577
# 2021-07-19    0.206267
# Freq: D, Length: 200, dtype: float64

# %%
ls.head()
# Out:
# 2021-01-01   -0.022578
# 2021-01-02    0.029524
# 2021-01-03   -0.076704
# 2021-01-04   -0.072829
# 2021-01-05    0.504664
# Freq: D, dtype: float64

# %%
ls = ls.cumsum()

# %%
ls
# Out:
# 2021-01-01   -0.022578
# 2021-01-02    0.006946
# 2021-01-03   -0.069758
# 2021-01-04   -0.142588
# 2021-01-05    0.362076
#                 ...
# 2021-07-15   -5.151733
# 2021-07-16   -3.373785
# 2021-07-17   -3.113988
# 2021-07-18   -2.999412
# 2021-07-19   -2.793145
# Freq: D, Length: 200, dtype: float64

# %%
ls.plot(kind="line",c="r")
plt.title(" basic plot")
plt.show()

# %%
df = pd.DataFrame(
    np.random.randn(200, 5),
    index=ls.index,
    columns=["column_1", "column_2", "column_3", "column_4", "column_5"],
)

# %%
df = df.cumsum()

# %%
df
# Out:
#              column_1  column_2  column_3   column_4   column_5
# 2021-01-01  -0.335555  1.450128 -0.774850  -1.046616  -0.518344
# 2021-01-02   0.101829  1.800515 -0.384931  -0.913981   0.234343
# 2021-01-03   0.810225  1.044013 -1.428242  -1.011097  -0.155103
# 2021-01-04   0.364126 -0.182888 -0.663434   0.101014  -0.164359
# 2021-01-05  -0.553610 -2.165537 -0.180274   0.458642  -2.546430
# ...               ...       ...       ...        ...        ...
# 2021-07-15  10.350251  7.958286  7.357640  15.970073  12.947721
# 2021-07-16  10.073078  6.435417  6.136006  15.111360  13.675554
# 2021-07-17   9.101558  6.832611  6.311959  14.191903  13.858896
# 2021-07-18   9.823032  7.572433  5.553072  16.094716  13.131169
# 2021-07-19   9.253523  7.812630  3.797119  16.668609  13.047272
#
# [200 rows x 5 columns]

# %%
df.head(10)
# Out:
#             column_1  column_2  column_3  column_4  column_5
# 2021-01-01 -0.335555  1.450128 -0.774850 -1.046616 -0.518344
# 2021-01-02  0.101829  1.800515 -0.384931 -0.913981  0.234343
# 2021-01-03  0.810225  1.044013 -1.428242 -1.011097 -0.155103
# 2021-01-04  0.364126 -0.182888 -0.663434  0.101014 -0.164359
# 2021-01-05 -0.553610 -2.165537 -0.180274  0.458642 -2.546430
# 2021-01-06 -1.447731 -3.451788 -0.444372 -0.126707 -3.121653
# 2021-01-07 -1.334452 -3.822183 -1.831753  1.083969 -3.077412
# 2021-01-08 -1.769837 -3.387807 -0.638122  1.192803 -3.417228
# 2021-01-09 -2.421863 -4.171757  0.366536  1.657337 -2.729371
# 2021-01-10 -4.842535 -5.156465  0.934512  0.086976 -2.863055

# %%
plt.Figure(figsize=(8,8))
df.plot()
plt.show()

# %%
notes = [10,20,30,40,50,60,70,80,90,99]
study_hours = [2,3,4,5,6,7,8,9,5,6]
exam_notes = pd.DataFrame(notes,columns=["notes"])
exam_notes["study_hours"]=pd.Series(study_hours)

# %%
exam_notes.plot(x="study_hours",y="notes",color="red")
# Out:
# <Axes: xlabel='study_hours'>

# %%
x = pd.Series(["A","B","C","D"])
y = pd.Series([12,13,14,15])
df = pd.DataFrame({"Letters": x,"Numbers":y})

df.index = x

# %%
df
# Out:
#   Letters  Numbers
# A       A       12
# B       B       13
# C       C       14
# D       D       15

# %%
df.plot(kind="bar",color="green")
plt.xlabel("letters")
plt.ylabel("numbers")
# Out:
# Text(0, 0.5, 'numbers')

# %%
df = pd.DataFrame(np.random.rand(7,5) ,columns=["ROHAN","RAJ","RANI","VIHSU","YASHU"])

# %%
df.plot(figsize=(8,8),kind="bar")
# Out:
# <Axes: >

# %%
df.plot.bar(figsize=(8,8),stacked = True)
# Out:
# <Axes: >

# %%
df.plot(figsize=(8,8),kind="barh")
# Out:
# <Axes: >

# %%
df.plot.barh(figsize=(8,8),stacked = True)
# Out:
# <Axes: >

# %%
note1 = [23,34,45,67,54,67,34,78,56,78]
note2 = [65,54,67,34,67,45,34,67,45,34]
final_note = [34,45,32,56,43,23,56,43,56,34]

notes = pd.DataFrame({"note1":note1 , "note2":note2 , "final_note":final_note})

# %%
notes
# Out:
#    note1  note2  final_note
# 0     23     65          34
# 1     34     54          45
# 2     45     67          32
# 3     67     34          56
# 4     54     67          43
# 5     67     45          23
# 6     34     34          56
# 7     78     67          43
# 8     56     45          56
# 9     78     34          34

# %%
notes.plot.hist(figsize=(8, 8), alpha=0.5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
notes.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
notes['note1'].plot(kind="hist",alpha = 0.1 )
# Out:
# <Axes: ylabel='Frequency'>

# %%
notes.plot.hist(figsize=(8, 8), alpha=0.5,orientation = "horizontal")
# Out:
# <Axes: xlabel='Frequency'>

# %%
notes
# Out:
#    note1  note2  final_note
# 0     23     65          34
# 1     34     54          45
# 2     45     67          32
# 3     67     34          56
# 4     54     67          43
# 5     67     45          23
# 6     34     34          56
# 7     78     67          43
# 8     56     45          56
# 9     78     34          34

# %%
notes.head()
# Out:
#    note1  note2  final_note
# 0     23     65          34
# 1     34     54          45
# 2     45     67          32
# 3     67     34          56
# 4     54     67          43

# %%
notes.plot(kind="box")
# Out:
# <Axes: >

# %%
notes.plot(kind="scatter", x="note1", y="note2",color="red",grid=True)
# Out:
# <Axes: xlabel='note1', ylabel='note2'>
